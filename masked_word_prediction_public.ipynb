# %% [markdown]
# <a href="https://colab.research.google.com/github/Aishwarya-Rashinkar/Covidgram-app/blob/main/masked_word_prediction_public.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![thumbnail.png](data:image/png;base64,...)

# %% [markdown]
# By Eric Fillion at Vennify.ai
#
# https://www.vennify.ai/

# %% [markdown]
# https://happytransformer.com/

# %%
pip install happytransformer

# %%
from happytransformer import HappyWordPrediction

# %%
happy_wp = HappyWordPrediction("BERT", "bert-base-uncased")
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 06/30/2021 03:57:38 - INFO - happytransformer.happy_transformer -   Using model: cuda

# %%
result = happy_wp.predict_mask("I think therefore I [MASK]", top_k=3)

# %%
print(result)
# Out:
# [WordPredictionResult(token='.', score=0.9096486568450928), WordPredictionResult(token=';', score=0.05662906914949417), WordPredictionResult(token='!', score=0.02144462615251541)]

# %%
result = happy_wp.predict_mask("I think therefore I [MASK]", top_k=3)

# %%
print(result)
# Out:
# [WordPredictionResult(token='am', score=0.9227073788642883), WordPredictionResult(token='think', score=0.006913329474627972), WordPredictionResult(token='.', score=0.0058214738965034485)]

# %%
happy_wp.train("train.txt")
# Out:
# 06/30/2021 03:59:11 - INFO - happytransformer.happy_transformer -   Preprocessing dataset...
# ...
# Dataset text downloaded and prepared to /root/.cache/huggingface/datasets/text/default-376cb0208a67a511/0.0.0/e16f44aa1b321ece1f87b07977cc5d70be93d69b20486d6dacd62e12cf25c9a5. Subsequent calls will reuse this data.
# ...
# 06/30/2021 03:59:11 - INFO - happytransformer.happy_transformer -   Training...
# ***** Running training *****
#   Num examples = 1
#   Num Epochs = 3
#   Instantaneous batch size per device = 1
#   Total train batch size (w. parallel, distributed & accumulation) = 1
#   Gradient Accumulation steps = 1
#   Total optimization steps = 3
#     <div>
#
#       <progress value='3' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3/3 00:00, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
# ...

# %%
print(result[0].token)
# Out:
# am

# %% [markdown]
# https://happytransformer.com/word-prediction/finetuning/
